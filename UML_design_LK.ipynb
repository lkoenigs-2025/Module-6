# %% [markdown]
# <a href="https://colab.research.google.com/github/lkoenigs-2025/Module-6/blob/main/UML_design_LK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Reflections:
#
# 1. The Game class is the controller of the entire hangman game. It receives guessed letters from the player class, checks with the word class if the guess is correct and updates the hangman class.
#
# 2. The game class was the hardest to design because it has the responsibility of coordinating with the other classes and making sure the game runs properly.
#
# 3. The controller should not be the one to guess letters and store them within a list. The player class takes the responsibility and allows the controller to do the other work.
#
# 4. I think the player class will be the easiest to reuse because it's task is simple and contained. It collects the letters and organizes them into a list.

# %%
@startuml

class Game {
-word: Word
-hangman: Hangman
-player: Player
-game_on: bool

+ __init__(player, game_on)
+ run_game()
+ reset_game()
+ check_win()
+ check_lost()
}

class Player {
- guessed_letters: list
+ choose_letter()
}

class Word {
- given_word : string
- correct_letters : dict
+ letter_in_word()
+ reset_word()
}

class Hangman {
- mistake : int
- part_of_body: list
+ add_to_man()
+ reset_man()
}


Game --> Player : controls
Game --> Word : checks
Game --> Hangman : updates



@enduml
