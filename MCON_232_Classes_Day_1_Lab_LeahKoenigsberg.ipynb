# %% [markdown]
# <a href="https://colab.research.google.com/github/lkoenigs-2025/Module-6/blob/main/MCON_232_Classes_Day_1_Lab_LeahKoenigsberg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## MCON 232 Classes Day 2 Lab
# ### your name :
# Leah Koenigsberg

# %%
class Pet:

  country_of_origin = "USA"
  num_pets = 0

  def __init__(self, name: str, age: int, owner: str)-> None:
    self.__name = name
    self.__age = age
    self.__owner = owner
    Pet.count_pets()

  def get_name(self)->str:
    return self.__name

  def get_age(self)->str:
    return self.__age

  def get_owner(self)-> str:
    return self.__owner

  def set_name(self, name:str)-> None:
    self.__name = name

  def set_age(self, age:int)-> None:
    self.__age = age

  def set_owner(self, owner:str)-> None:
    self.__owner = owner

  @classmethod
  def count_pets(cls):
    cls.num_pets +=1

  #__str__: return f string and it will give u a string,
  #and when u print any objet it will call it automatically

  def __str__(self):
    return f"{self.__name} {self.__age} {self.__owner}"

#Create two pets
p1 = Pet("Fifi", "2", "Reizi")
p2 = Pet("Rufus", "5", "Ruchama")


print(p1.get_age())
print(p2.get_age())
print(p1.get_name())
print(p2.get_name())

p2.country_of_origin = "France"

print(p1.country_of_origin)
print(p2.country_of_origin)

print(p1.num_pets)

#will print str instead of the type
print(p1)
# Out:
# 2
# 5
# Fifi
# Rufus
# USA
# France
# 2
# Fifi 2 Reizi

# %%
class Veterinarian:
  #pass the class pet by referance
  def __init__(self, name:str, store:str, client: Pet) -> None:
    self._name = name
    self.store = store
    self.client = client

  def get_pet(self) -> str:
    return self.client.get_name()

vet1 = Veterinarian("Dr. Green", "MS Pets", p1)
print(vet1.get_pet())
# Out:
# Fifi

# %%
#__str__: return f string and it will give u a string,
#and when u print any objet it will call it automatically

def __str__(self):
  return f"{self.__name}{self.__age}{self.__owner}"
print(p1)
# Out:
# Fifi 2 Reizi
